# %% [markdown]
# Please follow the instructions carefully. Write all your code in a `Code` cell, and your explanations in a `Markdown` cell. Make sure that your code compiles correctly either by selecting a given cell and clicking the `Run` button, or by hitting `shift`+`enter` or `shift`+`return`.

# %% [markdown]
# ### 1. Import `numpy`, `numpy.linalg`, `matplotlib.pyplot`, and `pandas`. Use the appropriate aliases when importing these modules.

# %%
# code for question 1

import numpy as np
from numpy import linalg as la
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### 2. Load the data from the file named `data_stock_returns.csv` into a `DatFrame` called `returns`. The file `data_stock_returns.csv` contains daily returns of a number of stocks selected from the S&P 500 universe. The rows of the csv file represent the returns over a number of days, and the columns represent individual stocks labeled by their NYSE ticker symbol, e.g., Apple stock is labeled `AAPL`.

# %%
# code for question 2
returns = pd.read_csv('data_stock_returns.csv')
returns = returns.set_index('Date')
returns
# Out:
#                 ATVI      CHTR     CMCSA       CTL       DIS     DISCA  \
# Date
# 2019-01-02  0.009829  0.010542  0.009354  0.018961 -0.006221  0.043115
# 2019-01-03 -0.036155 -0.001703  0.007825  0.004524 -0.024525 -0.005824
# 2019-01-04  0.039127  0.051651  0.033218  0.027974  0.030381  0.017754
# 2019-01-07  0.027806 -0.004204 -0.010668  0.021706  0.008630  0.014810
# 2019-01-08  0.029859 -0.002524  0.008152  0.025441  0.007748  0.026410
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-24 -0.001359  0.000291  0.009703 -0.002277  0.004207  0.003943
# 2019-12-26  0.001359  0.010077  0.009833 -0.003807  0.002818  0.007540
# 2019-12-27  0.005081 -0.004209  0.002887  0.023371  0.000343 -0.004517
# 2019-12-30 -0.005251 -0.001262  0.001772 -0.024134 -0.013678 -0.011231
# 2019-12-31  0.009129  0.004132 -0.004659  0.008362  0.005964 -0.000611
#
#                DISCK      DISH        EA        FB  ...       NEE        NI  \
# Date                                                ...
# 2019-01-02  0.031979  0.035795  0.018333  0.034415  ... -0.023222 -0.011107
# 2019-01-03  0.002515  0.020651 -0.020871 -0.029469  ... -0.002476  0.001196
# 2019-01-04  0.019072  0.068034  0.070034  0.046061  ...  0.018249  0.017378
# 2019-01-07  0.014271  0.011252  0.036862  0.000725  ... -0.001450  0.005467
# 2019-01-08  0.020041  0.002793  0.016194  0.031937  ...  0.007287  0.018519
# ...              ...       ...       ...       ...  ...       ...       ...
# 2019-12-24  0.007496  0.001956  0.007026 -0.005154  ...  0.007219 -0.000729
# 2019-12-26  0.004212  0.008617 -0.000369  0.012933  ...  0.006011 -0.002921
# 2019-12-27 -0.005511 -0.004994 -0.000738  0.001491  ...  0.002271 -0.002196
# 2019-12-30 -0.008161 -0.015700 -0.013930 -0.017891  ... -0.005043  0.008393
# 2019-12-31 -0.000656  0.002258  0.005409  0.004101  ...  0.003599  0.011561
#
#                  NRG       PEG       PNW       PPL        SO       SRE  \
# Date
# 2019-01-02 -0.038352 -0.023718 -0.027728 -0.007796 -0.004564 -0.013306
# 2019-01-03 -0.009491 -0.000197  0.010085 -0.003564  0.014082  0.004579
# 2019-01-04  0.033601  0.010764  0.012229  0.030242  0.008310  0.029491
# 2019-01-07  0.009179  0.002139 -0.001890  0.001384 -0.002239 -0.000181
# 2019-01-08  0.015114  0.003878  0.014904  0.013059  0.028071  0.027595
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-24 -0.004752 -0.001537 -0.001350 -0.001122 -0.002057  0.000598
# 2019-12-26 -0.016684  0.002049  0.001012 -0.002530  0.000633  0.006418
# 2019-12-27  0.000000 -0.000853 -0.001125 -0.000281  0.004580  0.001446
# 2019-12-30  0.000000  0.001535  0.004492  0.004214 -0.001893  0.001192
# 2019-12-31  0.013168  0.006456  0.007590  0.005870  0.005667  0.002843
#
#                  WEC       XEL
# Date
# 2019-01-02 -0.024556 -0.021542
# 2019-01-03  0.002660 -0.003948
# 2019-01-04  0.007352  0.009738
# 2019-01-07 -0.004552 -0.004339
# 2019-01-08  0.010249  0.011530
# ...              ...       ...
# 2019-12-24  0.001529  0.003905
# 2019-12-26  0.001418 -0.001114
# 2019-12-27  0.006085  0.005242
# 2019-12-30 -0.001518  0.002690
# 2019-12-31  0.000651  0.003155
#
# [252 rows x 488 columns]

# %% [markdown]
# ### 3. View the `head` of the `returns` `DataFrame`

# %%
# code for question 3
returns.head()
# Out:
#                 ATVI      CHTR     CMCSA       CTL       DIS     DISCA  \
# Date
# 2019-01-02  0.009829  0.010542  0.009354  0.018961 -0.006221  0.043115
# 2019-01-03 -0.036155 -0.001703  0.007825  0.004524 -0.024525 -0.005824
# 2019-01-04  0.039127  0.051651  0.033218  0.027974  0.030381  0.017754
# 2019-01-07  0.027806 -0.004204 -0.010668  0.021706  0.008630  0.014810
# 2019-01-08  0.029859 -0.002524  0.008152  0.025441  0.007748  0.026410
#
#                DISCK      DISH        EA        FB  ...       NEE        NI  \
# Date                                                ...
# 2019-01-02  0.031979  0.035795  0.018333  0.034415  ... -0.023222 -0.011107
# 2019-01-03  0.002515  0.020651 -0.020871 -0.029469  ... -0.002476  0.001196
# 2019-01-04  0.019072  0.068034  0.070034  0.046061  ...  0.018249  0.017378
# 2019-01-07  0.014271  0.011252  0.036862  0.000725  ... -0.001450  0.005467
# 2019-01-08  0.020041  0.002793  0.016194  0.031937  ...  0.007287  0.018519
#
#                  NRG       PEG       PNW       PPL        SO       SRE  \
# Date
# 2019-01-02 -0.038352 -0.023718 -0.027728 -0.007796 -0.004564 -0.013306
# 2019-01-03 -0.009491 -0.000197  0.010085 -0.003564  0.014082  0.004579
# 2019-01-04  0.033601  0.010764  0.012229  0.030242  0.008310  0.029491
# 2019-01-07  0.009179  0.002139 -0.001890  0.001384 -0.002239 -0.000181
# 2019-01-08  0.015114  0.003878  0.014904  0.013059  0.028071  0.027595
#
#                  WEC       XEL
# Date
# 2019-01-02 -0.024556 -0.021542
# 2019-01-03  0.002660 -0.003948
# 2019-01-04  0.007352  0.009738
# 2019-01-07 -0.004552 -0.004339
# 2019-01-08  0.010249  0.011530
#
# [5 rows x 488 columns]

# %% [markdown]
# ### 4. View the `tail` of the `returns` `DataFrame`

# %%
# code for question 4
returns.tail()
# Out:
#                 ATVI      CHTR     CMCSA       CTL       DIS     DISCA  \
# Date
# 2019-12-24 -0.001359  0.000291  0.009703 -0.002277  0.004207  0.003943
# 2019-12-26  0.001359  0.010077  0.009833 -0.003807  0.002818  0.007540
# 2019-12-27  0.005081 -0.004209  0.002887  0.023371  0.000343 -0.004517
# 2019-12-30 -0.005251 -0.001262  0.001772 -0.024134 -0.013678 -0.011231
# 2019-12-31  0.009129  0.004132 -0.004659  0.008362  0.005964 -0.000611
#
#                DISCK      DISH        EA        FB  ...       NEE        NI  \
# Date                                                ...
# 2019-12-24  0.007496  0.001956  0.007026 -0.005154  ...  0.007219 -0.000729
# 2019-12-26  0.004212  0.008617 -0.000369  0.012933  ...  0.006011 -0.002921
# 2019-12-27 -0.005511 -0.004994 -0.000738  0.001491  ...  0.002271 -0.002196
# 2019-12-30 -0.008161 -0.015700 -0.013930 -0.017891  ... -0.005043  0.008393
# 2019-12-31 -0.000656  0.002258  0.005409  0.004101  ...  0.003599  0.011561
#
#                  NRG       PEG       PNW       PPL        SO       SRE  \
# Date
# 2019-12-24 -0.004752 -0.001537 -0.001350 -0.001122 -0.002057  0.000598
# 2019-12-26 -0.016684  0.002049  0.001012 -0.002530  0.000633  0.006418
# 2019-12-27  0.000000 -0.000853 -0.001125 -0.000281  0.004580  0.001446
# 2019-12-30  0.000000  0.001535  0.004492  0.004214 -0.001893  0.001192
# 2019-12-31  0.013168  0.006456  0.007590  0.005870  0.005667  0.002843
#
#                  WEC       XEL
# Date
# 2019-12-24  0.001529  0.003905
# 2019-12-26  0.001418 -0.001114
# 2019-12-27  0.006085  0.005242
# 2019-12-30 -0.001518  0.002690
# 2019-12-31  0.000651  0.003155
#
# [5 rows x 488 columns]

# %% [markdown]
# ### 5. How many stocks are in this `DataFrame`?

# %%
# code for question 5
len(returns.columns)
# Out:
# 488

# %% [markdown]
# **ANSWER FOR QUESTION 5**: 488 stocks

# %% [markdown]
# ### 6. Over how many days are these stock returns reported?

# %%
# code for question 6
len(returns.index)
# Out:
# 252

# %% [markdown]
# **ANSWER FOR QUESTION 6**: 252 days

# %% [markdown]
# ### 7. Extract the returns of the Amazon stock only, which has a ticker symbol `AMZN`. Save it in a `Series` called `amzn_returns`.

# %%
# code for question 7
amzn_returns = returns.AMZN
amzn_returns
# Out:
# Date
# 2019-01-02    0.024440
# 2019-01-03   -0.025566
# 2019-01-04    0.048851
# 2019-01-07    0.033776
# 2019-01-08    0.016476
#                 ...
# 2019-12-24   -0.002116
# 2019-12-26    0.043506
# 2019-12-27    0.000551
# 2019-12-30   -0.012328
# 2019-12-31    0.000514
# Name: AMZN, Length: 252, dtype: float64

# %% [markdown]
# ### 8. Plot the Amazon stock returns extracted in the above cell.

# %%
# code for question 8
amzn_plot = amzn_returns.plot()
amzn_plot.set_title('Amazon Stock Daily Returns')
amzn_plot.set_xlabel('Dates')
amzn_plot.set_ylabel('Returns')
plt.show()

# %% [markdown]
# ### 9. Plot the cumulative sum of the Amazon stock returns using the method `.cumsum()` which acts directly on the `amzn_returns` `Series`.

# %%
# code for question 9
amzn_plot_cumsum = amzn_returns.cumsum().plot()
amzn_plot_cumsum.set_title('Amazon Cumulative Sum Of Stock Returns Over Time')
amzn_plot_cumsum.set_xlabel('Dates')
amzn_plot_cumsum.set_ylabel('Cumulative Sum of Stock Returns')
plt.show()

# %%
# the module below will allow us to perform linear regression
import statsmodels.api as sm

# %% [markdown]
# The function `lin_reg(x,y)` given below performs ordinary least squares (OLS) linear regression using `sm.OLS` from the `statsmodels.api` module.
#
# The code enclosed in `''' '''` is the docstring of the function `lin_reg`.
#
# `x` in the `lin_reg` function is a matrix that contains the regressors, and `y` represents the vector containing the dependent variable. Note that `x` might contain one vector or multiple vectors. In the case that `x` contains one vector $x$, the regression gives:
#
# $$ y = \beta_0 + \beta_1 x $$
#
# In the case that `x` contains multiple vectors $x_1, \dots, x_k$, the regression becomes:
#
# $$ y = \beta_0 + \beta_1 x_1 + \dots + \beta_k x_k$$
#
# The $\beta$'s are the regression coefficients obtained using least squares. Note that `sm.add_constant` is used in the function below to make `x` look like the matrix $A$ we use in least squares, whose first column contains all ones.

# %%
def lin_reg(x, y):
    '''
    ordinary linear regression using least-squares
    
    Parameters
    ----------  
    x: regressors (numpy array)
    y: dependent variable (numpy array)
    
    Returns
    -------
    coefficients: regression coefficients (pandas Series)
    residuals: regression residuals (numpy array)
    r_squared: correlation coefficient (float)
    
    '''
    x = sm.add_constant(x)
    model = sm.OLS(y, x).fit()
    coefficients = model.params
    residuals = model.resid
    r_squared = model.rsquared
    return coefficients, residuals, r_squared

# %% [markdown]
# ### 10. Let's try to use the above function. Extract (as numpy array) the stock returns of:
#
# - Apple (ticker symbol `AAPL`) and call it `aapl`
# - Intel (ticker symbol `INTC`) and call it `intc`
# - Microsoft (ticker symbol `MSFT`) and call it `msft`
# - IBM (ticker symbol `IBM`) and call it `ibm`
#
# ### Let `y` be the Apple stock returns, and `x` be the Intel stock returns. Use the `lin_reg` function defined above to find $y=\beta_0 + \beta_1 x$.

# %%
# code for question 10
aapl = returns[['AAPL']].to_numpy().flatten()
intc = returns[['INTC']].to_numpy().flatten()
msft = returns[['MSFT']].to_numpy().flatten()
ibm = returns[['IBM']].to_numpy().flatten()
aapl_pred_lin_reg_1 = lin_reg(intc, aapl)
aapl_pred_lin_reg_1
# Out:
# (array([0.00195633, 0.53526326]),
#  array([-2.52404291e-03, -7.65933995e-02,  7.97028504e-03, -6.67246823e-03,
#          1.35529430e-02,  1.18641773e-02, -4.86231162e-03, -1.58858897e-02,
#         -1.07247855e-02,  1.55432797e-02,  1.53879143e-02,  1.95803633e-04,
#         -3.70848711e-03, -1.45523640e-02,  5.75186562e-03, -2.98588472e-02,
#          6.07322952e-02, -7.48569899e-03, -1.04235826e-02,  5.27654517e-02,
#          9.96878256e-03, -1.94589822e-02,  2.06971946e-02,  6.48551194e-03,
#         -3.81541327e-03, -1.38417615e-02,  3.47531369e-03, -6.95626072e-03,
#         -6.81518375e-03, -1.10207955e-02, -1.91331554e-03, -1.30640488e-02,
#         -1.68351198e-02,  6.76203009e-03,  4.24486981e-03,  9.54731773e-03,
#         -8.35287084e-03, -7.78645871e-03,  6.84093922e-04,  4.75687213e-03,
#          5.76077975e-04, -6.07705929e-03, -5.36058529e-03,  1.34583709e-02,
#          8.86678487e-03, -1.26986285e-02, -3.88936897e-04,  1.62516308e-02,
#          1.42672640e-03, -4.24580399e-03,  1.68345472e-03,  4.79310242e-03,
#          1.41282319e-02,  1.24745189e-03, -1.46587419e-02, -3.96448919e-03,
#          7.97416207e-03,  8.02074770e-03,  7.27238154e-03, -3.01211703e-03,
#          1.43662552e-02, -5.56515688e-03, -3.13990660e-02,  5.17430384e-03,
#         -2.13805067e-02, -4.54414250e-03,  2.10639054e-02,  2.62185691e-02,
#         -5.72985208e-03, -2.83637716e-03, -4.93136347e-03,  5.35330253e-03,
#         -1.24794062e-03,  5.19690685e-03, -1.49440443e-03,  1.04384564e-02,
#         -8.15974419e-03,  8.46604696e-03,  4.01697325e-04, -5.91167101e-03,
#         -9.52201472e-03, -9.40007367e-03,  2.80325759e-03,  4.39061514e-03,
#         -1.06142836e-02,  1.49425402e-02,  6.33436334e-05, -9.97780438e-03,
#         -4.97970601e-03,  7.30872057e-03,  1.20351391e-02,  1.02530673e-02,
#         -1.34107666e-02,  3.30340353e-03,  2.01591039e-03, -3.89440267e-03,
#          9.31764553e-03,  1.58509002e-02,  3.73082950e-03, -3.13283721e-03,
#         -8.30182396e-03, -1.30952344e-02,  1.16938821e-02, -2.63036099e-03,
#          1.40085229e-02, -4.65728593e-03,  8.07528318e-03,  3.26262755e-03]),
#  0.3050299157977573)

# %% [markdown]
# ### 11. Plot the cumulative sum of the Apple returns prediction from least squares on top of the cumulative sum of the actual Apple returns. How well do the Intel stock returns describe the Apple stock returns? Answer this question using a quantitative measure of choice to describe how well the regression describes the actual data (you should research what is standard procedure in answering these types of questions).

# %%
# code for question 11
days = np.arange(252)
aapl_plot_returns_cumsum = aapl.cumsum()
aapl_pred_1 = aapl_pred_lin_reg_1[0][0] + aapl_pred_lin_reg_1[0][1]*intc
aapl_plot_pred_cumsum = aapl_pred_1.cumsum()
plt.plot(days, aapl_plot_returns_cumsum)
plt.plot(days, aapl_plot_pred_cumsum)
plt.title('Cumulative Sum of Apple Returns Prediction vs. Cumulative Sum of Actual Apple Returns')
plt.xlabel('Days')
plt.ylabel('Cumulative Sum of Stock Returns')
plt.show()
print("R^2 = ", aapl_pred_lin_reg_1[2])
# Out:
# R^2 =  0.3050299157977573

# %% [markdown]
# **ANSWER FOR QUESTION 11**: The regression describes the data in a consistent way as shown by the graph and an R^2 value of 0.3050299157977573.

# %% [markdown]
# ### 12. Now, let `y` be the Apple stock returns, and `x` be the Intel, Microsoft, and IBM stock returns. Use the `lin_reg` function defined above to find $y=\beta_0 + \beta_1 x_1 + \beta_2 x_2 + \beta_3 x_3$, where $x_1$ represents Intel returns, $x_2$ represents Microsoft returns, and $x_3$ represents IBM returns.

# %%
# code for question 12
aapl_pred_lin_reg_2 = lin_reg(np.array([intc, msft, ibm]).T, aapl)
plt.plot(days, aapl_plot_returns_cumsum)
plt.plot(days, aapl_plot_pred_cumsum)
plt.title('Cumulative Sum of Apple Returns Prediction vs. Cumulative Sum of Actual Apple Returns')
plt.xlabel('Days')
plt.ylabel('Cumulative Sum of Stock Returns')
plt.show()
print("R^2 = ", aapl_pred_lin_reg_2[2])
# Out:
# R^2 =  0.4704730705676301

# %% [markdown]
# **ANSWER FOR QUESTION 13**: The regression describes the data in relatively consistent way as shown by the graph and an R^2 value of 0.4704730705676301.

# %% [markdown]
# The file `SPY.csv` contains the prices of SPDR S&P 500 ETF Trust. This Exchange Traded Fund (ETF) contains a collection of assets currently present in the S&P 500 index.
#
# ### 14. Load `SPY.csv` into a DataFrame called `spy_prices` using the `read_csv` method in `pandas`. Make sure to make the 'Date' column to be your index column. To do that, read the docstring for `read_csv`.

# %%
# code for question 14
spy_prices = pd.read_csv('SPY.csv')
spy_prices = spy_prices.set_index('Date')
spy_prices
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2015-01-02  206.880005  204.179993  206.380005  205.429993  121465900.0
# 2015-01-05  204.369995  201.350006  204.169998  201.720001  169632600.0
# 2015-01-06  202.720001  198.860001  202.089996  199.820007  209151400.0
# 2015-01-07  202.720001  200.880005  201.419998  202.309998  125346700.0
# 2015-01-08  206.160004  203.990005  204.009995  205.899994  147217800.0
# ...                ...         ...         ...         ...          ...
# 2020-05-26  302.190002  295.459991  301.929993  299.079987   88951400.0
# 2020-05-27  303.570007  296.869995  302.119995  303.529999  104817400.0
# 2020-05-28  306.839996  302.239990  304.649994  302.970001   90405200.0
# 2020-05-29  304.959991  299.470001  302.459991  304.320007  119265700.0
# 2020-06-01  306.209991  303.059998  303.619995  305.549988   55758300.0
#
#              Adj Close
# Date
# 2015-01-02  184.260223
# 2015-01-05  180.932541
# 2015-01-06  179.228363
# 2015-01-07  181.461731
# 2015-01-08  184.681763
# ...                ...
# 2020-05-26  297.769623
# 2020-05-27  302.200134
# 2020-05-28  301.642609
# 2020-05-29  302.986694
# 2020-06-01  304.211273
#
# [1362 rows x 6 columns]

# %% [markdown]
# ### 15. Once you have downloaded the file into the `DataFrame`, observe all the available prices and dates. Show the head and tail of the `DataFrame`, and then answer the following questions:
#
# (a) Which types of prices are reported?
#
# (b) From which date to which date are these prices reported (in the entire DataFrame)?

# %%
# code for question 15
spy_prices.head()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2015-01-02  206.880005  204.179993  206.380005  205.429993  121465900.0
# 2015-01-05  204.369995  201.350006  204.169998  201.720001  169632600.0
# 2015-01-06  202.720001  198.860001  202.089996  199.820007  209151400.0
# 2015-01-07  202.720001  200.880005  201.419998  202.309998  125346700.0
# 2015-01-08  206.160004  203.990005  204.009995  205.899994  147217800.0
#
#              Adj Close
# Date
# 2015-01-02  184.260223
# 2015-01-05  180.932541
# 2015-01-06  179.228363
# 2015-01-07  181.461731
# 2015-01-08  184.681763

# %%
spy_prices.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-05-26  302.190002  295.459991  301.929993  299.079987   88951400.0
# 2020-05-27  303.570007  296.869995  302.119995  303.529999  104817400.0
# 2020-05-28  306.839996  302.239990  304.649994  302.970001   90405200.0
# 2020-05-29  304.959991  299.470001  302.459991  304.320007  119265700.0
# 2020-06-01  306.209991  303.059998  303.619995  305.549988   55758300.0
#
#              Adj Close
# Date
# 2020-05-26  297.769623
# 2020-05-27  302.200134
# 2020-05-28  301.642609
# 2020-05-29  302.986694
# 2020-06-01  304.211273

# %% [markdown]
# **ANSWER FOR QUESTION 15**:
#
# (a) High, Low, Open, Close and Adjusted Close prices are reported
#
# (b) Prices are reported from 2015-01-02	to 2020-06-01.

# %% [markdown]
# ### 16. Retain only the Adjusted Close price in the `spy_prices` `DataFrame`. Call the resulting `Series` `spy_adjclose`.

# %%
# code for question 16
spy_adjclose = spy_prices.iloc[:,5]
spy_adjclose
# Out:
# Date
# 2015-01-02    184.260223
# 2015-01-05    180.932541
# 2015-01-06    179.228363
# 2015-01-07    181.461731
# 2015-01-08    184.681763
#                  ...
# 2020-05-26    297.769623
# 2020-05-27    302.200134
# 2020-05-28    301.642609
# 2020-05-29    302.986694
# 2020-06-01    304.211273
# Name: Adj Close, Length: 1362, dtype: float64

# %% [markdown]
# ### 17. Now, using the `pct_change` method in `pandas`, compute the returns on the Adjusted Close prices of SPY, and only retain the returns from '2019-01-01' to '2020-01-01'. Call the `Series` obtained `spy_returns`.

# %%
# code for question 17
spy_returns = spy_adjclose.pct_change().loc['2019-01-01':'2020-01-01']
spy_returns
# Out:
# Date
# 2019-01-02    0.001040
# 2019-01-03   -0.023863
# 2019-01-04    0.033496
# 2019-01-07    0.007885
# 2019-01-08    0.009395
#                 ...
# 2019-12-24    0.000031
# 2019-12-26    0.005323
# 2019-12-27   -0.000248
# 2019-12-30   -0.005513
# 2019-12-31    0.002429
# Name: Adj Close, Length: 252, dtype: float64

# %% [markdown]
# ### 18. Perform SVD on `returns` data that contain assets from the S&P 500, and save the left singular vectors in an array called `U`, the singular values in an array called `sing_vals`, and the right singular vectros in an array called `V`. Retain the left singular vector corresponding to the largest singular value and call is `u_sigma1`.

# %%
# code for question 18
U, sing_vals, V = np.linalg.svd(returns, full_matrices=True)
u_sigma1 = U[:,0]
u_sigma1
# Out:
# array([-2.61377831e-02,  1.61545283e-01, -2.39072521e-01, -8.50919141e-02,
#        -6.50519613e-02, -6.54989459e-02, -3.42081872e-02, -9.61532142e-03,
#         2.61106863e-02, -3.66516290e-02, -2.17256697e-02, -6.56591169e-02,
#        -1.13175003e-01,  1.12292114e-01,  1.46262775e-02, -5.27029066e-02,
#        -9.20756297e-02,  4.15309183e-02, -4.19965671e-03, -8.25840670e-02,
#        -3.85878070e-02, -2.64600711e-02, -3.59552764e-02, -2.74447318e-02,
#        -2.07249932e-03,  6.85491747e-02, -4.53474533e-03, -2.22774569e-02,
#        -9.29941909e-02, -3.39398663e-02,  1.32384003e-02, -7.90552361e-02,
#        -1.16513989e-02, -2.66305482e-02,  3.52424919e-02, -4.31805646e-02,
#        -1.29146535e-02,  2.38675368e-02,  7.12326108e-04,  2.57816012e-02,
#         2.56389241e-02,  3.40711446e-02, -4.95426671e-03,  7.40438105e-02,
#        -5.17439770e-02,  2.92947976e-02,  2.66481863e-02, -2.99429626e-02,
#         1.22829586e-01,  1.28803364e-01, -4.99705119e-02, -6.84503255e-02,
#         3.36905714e-02,  1.35602920e-01, -6.34338329e-02, -5.86252369e-02,
#        -1.28833363e-01,  1.40783660e-02, -7.16362023e-02,  2.53219828e-02,
#        -2.31904800e-02,  1.46907121e-02, -6.14115928e-02, -5.41521550e-03,
#        -2.23006518e-02, -4.62398856e-03, -4.39217767e-02, -3.44093313e-02,
#        -9.57993064e-03,  1.42857267e-02,  4.97139207e-02, -1.11914273e-01,
#        -7.38694779e-02, -9.00157685e-03,  2.46015982e-02, -3.90102141e-02,
#        -1.82601643e-02,  2.05397429e-02, -5.53321224e-03,  3.01866406e-02,
#        -1.09927819e-02, -5.29504105e-02,  1.99118537e-02,  9.71068798e-03,
#         2.88297464e-02,  6.81562458e-03, -2.83906934e-02, -7.12416388e-02,
#         1.46135326e-03, -3.23069219e-02,  3.86810461e-02,  5.75431906e-02,
#         7.29677212e-02, -5.53409307e-02, -1.11888998e-02, -7.56724156e-02,
#         2.13029981e-02,  6.16491822e-03, -2.70721900e-02, -1.02049473e-01,
#         3.09257853e-02, -4.19852448e-02, -9.39247269e-03, -5.55899095e-03,
#        -2.05303695e-02, -3.49184193e-02, -1.62878009e-02,  4.01306003e-04,
#        -1.55226903e-02,  1.42204910e-02,  2.92187680e-02, -2.48367876e-02])

# %% [markdown]
# ### 19. `u_sigma1` is thought to track the market. To test that, we will perform a regression of `spy_returns` against this first left singular vector by letting `y=spy_returns` and `x=u_sigma1` and computing
#
# ### $$ y = \beta_0 + \beta_1 x$$
# ### using least squares regression.

# %%
# code for question 19
spy_lin_reg = lin_reg(u_sigma1, spy_returns)
spy_lin_reg
# Out:
# (const    0.000346
#  x1      -0.118992
#  dtype: float64,
#  Date
#  2019-01-02   -0.002416
#  2019-01-03   -0.004987
#  2019-01-04    0.004702
#  2019-01-07   -0.002587
#  2019-01-08    0.001308
#                  ...
#  2019-12-24   -0.000267
#  2019-12-26    0.003130
#  2019-12-27    0.001098
#  2019-12-30   -0.002383
#  2019-12-31   -0.000872
#  Length: 252, dtype: float64,
#  0.8987899218671398)

# %% [markdown]
# ### 20. Plot the cumulative sum of the result from the regression on top of the cumulative sum of `spy_returns`. What do you notice? Answer this question using a quantitative measure of choice to describe how well the regression describes the actual data (you should research what is standard procedure in answering these types of questions).

# %%
# code for question 20
spy_returns_cumsum = spy_returns.cumsum()
spy_pred = spy_lin_reg[0][0] + spy_lin_reg[0][1]*u_sigma1
spy_plot_pred_cumsum = spy_pred.cumsum()
plt.plot(days, spy_returns_cumsum)
plt.plot(days, spy_plot_pred_cumsum)
plt.title('Cumulative Sum of SPY Returns Prediction vs. Cumulative Sum of Actual SPY Returns')
plt.xlabel('Days')
plt.ylabel('Cumulative Sum of Stock Returns')
plt.show()
print("R^2 = ", spy_lin_reg[2])
# Out:
# R^2 =  0.8987899218671398

# %% [markdown]
# **ANSWER FOR QUESTION 20**: The cumulative sums of the regression are generally similar to the cumulative sum of the spy_returns. The regression describes the data in very consistent way shown by the graph and a high R^2 value of 0.8987899218671398.

# %% [markdown]
# # Congratulations! You have just implemented your first PCA regression to describe the returns on the S&P 500. Now let's shift gears a little and see how singular values and singular vectors of returns matrices are connected to eigenvalues and eigenvectors of correlation matrices.

# %% [markdown]
# ### 21. Compute the standardized returns of the S&P 500 and save you answer in a `DataFrame` called `sp500_standardized_returns`.

# %%
# code for question 21
sp500_standardized_returns = (returns-returns.mean())/returns.std()
sp500_standardized_returns
# Out:
#                 ATVI      CHTR     CMCSA       CTL       DIS     DISCA  \
# Date
# 2019-01-02  0.391715  0.623274  0.682788  0.772755 -0.527091  2.214992
# 2019-01-03 -1.648121 -0.281934  0.555334  0.190896 -1.836594 -0.365756
# 2019-01-04  1.691372  3.662371  2.671944  1.135997  2.091421  0.877613
# 2019-01-07  1.189148 -0.466820 -0.986145  0.883392  0.535321  0.722329
# 2019-01-08  1.280229 -0.342652  0.582569  1.033902  0.472276  1.334079
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-24 -0.104603 -0.134523  0.711893 -0.083192  0.218941  0.149325
# 2019-12-26  0.015998  0.588897  0.722673 -0.144835  0.119547  0.339001
# 2019-12-27  0.181104 -0.467184  0.143697  0.950488 -0.057506 -0.296845
# 2019-12-30 -0.277238 -0.249340  0.050812 -0.964075 -1.060581 -0.650883
# 2019-12-31  0.360671  0.149385 -0.485242  0.345585  0.344610 -0.090828
#
#                DISCK      DISH        EA        FB  ...       NEE        NI  \
# Date                                                ...
# 2019-01-02  1.736882  1.635478  0.735811  1.869720  ... -2.714286 -1.111620
# 2019-01-03  0.079309  0.915515 -0.950561 -1.790204  ... -0.428282  0.079813
# 2019-01-04  1.010775  3.168069  2.959763  2.536918  ...  1.855441  1.646922
# 2019-01-07  0.740711  0.468691  1.532867 -0.060411  ... -0.315214  0.493392
# 2019-01-08  1.065278  0.066574  0.643811  1.727726  ...  0.647523  1.757420
# ...              ...       ...       ...       ...  ...       ...       ...
# 2019-12-24  0.359520  0.026775  0.249436 -0.397224  ...  0.640024 -0.106593
# 2019-12-26  0.174793  0.343439 -0.068647  0.638995  ...  0.506895 -0.318861
# 2019-12-27 -0.372216 -0.303653 -0.084518 -0.016517  ...  0.094752 -0.248689
# 2019-12-30 -0.521253 -0.812581 -0.652016 -1.126907  ... -0.711167  0.776759
# 2019-12-31 -0.099049  0.041127  0.179899  0.133017  ...  0.241149  1.083570
#
#                  NRG       PEG       PNW       PPL        SO       SRE  \
# Date
# 2019-01-02 -2.823141 -2.893775 -2.923860 -0.873279 -0.706149 -1.600766
# 2019-01-03 -0.700163 -0.097827  1.014562 -0.459890  1.411865  0.339830
# 2019-01-04  2.469645  1.205140  1.237888  2.842341  0.756246  3.042892
# 2019-01-07  0.673201  0.179843 -0.232697  0.023472 -0.442065 -0.176665
# 2019-01-08  1.109722  0.386499  1.516402  1.163869  3.001027  2.837142
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-24 -0.351541 -0.257130 -0.176423 -0.221397 -0.421391 -0.092192
# 2019-12-26 -1.229249  0.169130  0.069578 -0.358885 -0.115762  0.539379
# 2019-12-27 -0.002003 -0.175838 -0.153003 -0.139246  0.332582 -0.000143
# 2019-12-30 -0.002003  0.108061  0.431981  0.299884 -0.402710 -0.027646
# 2019-12-31  0.966624  0.693001  0.754691  0.461651  0.456081  0.151416
#
#                  WEC       XEL
# Date
# 2019-01-02 -2.869759 -2.518638
# 2019-01-03  0.156715 -0.562652
# 2019-01-04  0.678486  0.958906
# 2019-01-07 -0.645257 -0.606135
# 2019-01-08  1.000671  1.158106
# ...              ...       ...
# 2019-12-24  0.030983  0.310436
# 2019-12-26  0.018593 -0.247594
# 2019-12-27  0.537601  0.459047
# 2019-12-30 -0.307860  0.175302
# 2019-12-31 -0.066703  0.227045
#
# [252 rows x 488 columns]

# %% [markdown]
# ### 22. Perform SVD on `sp500_standardized_returns` data and save the singular values in an array called `singvals_standardized_returns`.

# %%
# code for question 22
U, singvals_standardized_returns, V = np.linalg.svd(sp500_standardized_returns, full_matrices=True)

# %% [markdown]
# ### 23. Compute the correlation matrix of the S&P 500 returns and save the result as a `DataFrame` called `sp500_corr`. It is easiest to use the built in `pandas` method to compute correlation matrices.

# %%
# code for question 23
sp500_corr = returns.corr()
sp500_corr
# Out:
#            ATVI      CHTR     CMCSA       CTL       DIS     DISCA     DISCK  \
# ATVI   1.000000  0.206918  0.262801  0.077612  0.204631  0.167902  0.182100
# CHTR   0.206918  1.000000  0.505437  0.154453  0.269021  0.297209  0.304711
# CMCSA  0.262801  0.505437  1.000000  0.176776  0.369520  0.347829  0.354896
# CTL    0.077612  0.154453  0.176776  1.000000  0.105414  0.365380  0.371403
# DIS    0.204631  0.269021  0.369520  0.105414  1.000000  0.267041  0.294375
# ...         ...       ...       ...       ...       ...       ...       ...
# PPL    0.068130  0.143166  0.232142  0.125933  0.094228  0.119023  0.107557
# SO     0.027154  0.082080  0.130291 -0.061925  0.150702 -0.108276 -0.099986
# SRE    0.114697  0.185263  0.169756  0.024476  0.249978  0.038471  0.055280
# WEC    0.010774  0.138888  0.105805 -0.169695  0.119923 -0.172918 -0.169914
# XEL    0.038000  0.184257  0.193725 -0.117967  0.195905 -0.110884 -0.109743
#
#            DISH        EA        FB  ...       NEE        NI       NRG  \
# ATVI   0.136099  0.563535  0.372576  ...  0.012736  0.183840  0.148949
# CHTR   0.356974  0.210798  0.467210  ...  0.171468  0.146685  0.214851
# CMCSA  0.362213  0.165238  0.353877  ...  0.123246  0.204658  0.225813
# CTL    0.194719  0.144104  0.097236  ... -0.099621 -0.038359  0.088011
# DIS    0.236062  0.162910  0.251893  ...  0.142103  0.183875  0.128499
# ...         ...       ...       ...  ...       ...       ...       ...
# PPL    0.155584  0.186064  0.110712  ...  0.443621  0.418001  0.348481
# SO     0.067194  0.164438  0.034642  ...  0.659916  0.610121  0.328128
# SRE    0.187340  0.137067  0.192123  ...  0.598093  0.576184  0.350399
# **ANSWER FOR QUESTION 24**: Singular values come from the eignenvalues of AA^T. As the correlation matrix is AA^T/(n-1), the eigenvalues are also divided by n-1. Therefore, the relationship between the eigenvalues and the singular values is: eigenvalues = (singular values)^2/(n-1).

# %% [markdown]
# ### 25. What is the sum of the eigenvalues? Justify why the sum turns out to be what it is.

# %%
# code for question 25
eigvals_corr.sum()
# Out:
# (488.00000000000074+9.860761315262648e-32j)

# %% [markdown]
# **ANSWER FOR QUESTION 25**: The sum is 488 because the trace of the correlation matrix is 488 as all the values along the diagonal are 1 and the matrix is 488x488. The sum of the eigenvalues is equal to the trace, making the sum of the eigenvalues also 488.

# %% [markdown]
# ### 26. How are the eigenvectors of the correlation matrix `eigvecs_corr` connected to the left singular vectors of the standardized returns matrix in Question 22? Here you are expected to derive the relation theoretically.

# %%
eigvecs_corr
# Out:
# array([[ 0.03950456+0.j        ,  0.0116565 +0.j        ,
#          0.05677556+0.j        , ...,  0.01247675-0.00062971j,
#          0.00940072+0.j        , -0.00175394+0.j        ],
#        [ 0.03135706+0.j        ,  0.01577114+0.j        ,
#          0.03206589+0.j        , ..., -0.00082001+0.00408825j,
#         -0.00627164+0.j        ,  0.01405912+0.j        ],
#        [ 0.04426116+0.j        ,  0.0130926 +0.j        ,
#         -0.01257225+0.j        , ...,  0.00575467-0.00728564j,
#         -0.01204971+0.j        ,  0.0380922 +0.j        ],
#        ...,
#        [ 0.0208441 +0.j        ,  0.0876809 +0.j        ,
#         -0.05629435+0.j        , ...,  0.01829025-0.01908365j,
#         -0.0078708 +0.j        ,  0.00319397+0.j        ],
#        [ 0.00254706+0.j        ,  0.11947567+0.j        ,
#         -0.04623643+0.j        , ...,  0.00830245-0.02777466j,
#         -0.02268264+0.j        ,  0.10420899+0.j        ],
#        [ 0.01038698+0.j        ,  0.12151001+0.j        ,
#         -0.05546331+0.j        , ..., -0.10461009+0.00374572j,
#         -0.07895534+0.j        , -0.03417289+0.j        ]])

# %%
U
# Out:
# array([[-0.01325098, -0.20974553, -0.04794458, ...,  0.00245247,
#         -0.04104418, -0.06299408],
#        [-0.1776379 , -0.00287146,  0.23433435, ..., -0.00928899,
#         -0.05695268, -0.06299408],
#        [ 0.24726022,  0.04272599, -0.04119494, ..., -0.00737118,
#         -0.02519468, -0.06299408],
#        ...,
#        [-0.01427152,  0.03202055,  0.00235856, ...,  0.2090674 ,
#         -0.24588733, -0.06299408],
#        [-0.03865663, -0.01728148,  0.0420913 , ...,  0.38585822,
#         -0.1968886 , -0.06299408],
#        [ 0.01670622,  0.02499676,  0.04752299, ...,  0.38145793,
#         -0.40883468, -0.06299408]])

# %% [markdown]
# **ANSWER FOR QUESTION 26**: Let the matrix C be the correlation matrix. The correlation matrix is symmetric so therefore C can be diagonalized as C = XEX^T.
#
# We've also established that C = AA^T/(n-1) where A = USV^T.
#
# We also know (via Q24) that eigenvalues = (singular values)^2/(n-1).
#
# This results in E = S^2/(n-1) and XEX^T = US^2U^T/(n-1).
#
# Therefore, X = U --> The left singular vectors of returns are the eigenvectors of the correlation matrix scaled by n - 1.
